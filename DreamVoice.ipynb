# %%
! pip install SpeechRecognition
! pip install pyaudio
! pip install --upgrade pyaudio
! pip install wheel
! pip install google-api-python-client
! sudo apt-get install flac
! pip install monotonic
! pip install SpeechRecognition
# Out:
# Collecting SpeechRecognition
#   Downloading https://files.pythonhosted.org/packages/26/e1/7f5678cd94ec1234269d23756dbdaa4c8cfaed973412f88ae8adf7893a50/SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8MB)
#      |████████████████████████████████| 32.8MB 127kB/s
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.8.1
# Collecting pyaudio
#   Downloading https://files.pythonhosted.org/packages/ab/42/b4f04721c5c5bfc196ce156b3c768998ef8c0ae3654ed29ea5020c749a6b/PyAudio-0.2.11.tar.gz
# Building wheels for collected packages: pyaudio
#   Building wheel for pyaudio (setup.py) ... error
#   ERROR: Failed building wheel for pyaudio
#   Running setup.py clean for pyaudio
# Failed to build pyaudio
# Installing collected packages: pyaudio
#     Running setup.py install for pyaudio ... error
# ERROR: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-h72gfr01/pyaudio/setup.py'"'"'; __file__='"'"'/tmp/pip-install-h72gfr01/pyaudio/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-vdht1lfq/install-record.txt --single-version-externally-managed --compile Check the logs for full command output.
# Collecting pyaudio
#   Using cached https://files.pythonhosted.org/packages/ab/42/b4f04721c5c5bfc196ce156b3c768998ef8c0ae3654ed29ea5020c749a6b/PyAudio-0.2.11.tar.gz
# Building wheels for collected packages: pyaudio
#   Building wheel for pyaudio (setup.py) ... error
#   ERROR: Failed building wheel for pyaudio
#   Running setup.py clean for pyaudio
# Failed to build pyaudio
# Installing collected packages: pyaudio
#     Running setup.py install for pyaudio ... error
# ERROR: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-f9go47y6/pyaudio/setup.py'"'"'; __file__='"'"'/tmp/pip-install-f9go47y6/pyaudio/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-1jw7tuht/install-record.txt --single-version-externally-managed --compile Check the logs for full command output.
# Requirement already satisfied: wheel in /usr/local/lib/python3.6/dist-packages (0.36.2)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.6/dist-packages (1.7.12)
# Requirement already satisfied: six<2dev,>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (1.15.0)
# Requirement already satisfied: google-auth>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (1.17.2)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (0.0.4)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (3.0.1)
# Requirement already satisfied: httplib2<1dev,>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client) (0.17.4)
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client) (51.1.2)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client) (4.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client) (4.2.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth>=1.4.1->google-api-python-client) (0.4.8)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   flac
# 0 upgraded, 1 newly installed, 0 to remove and 12 not upgraded.
# Need to get 144 kB of archives.
# After this operation, 438 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 flac amd64 1.3.2-1 [144 kB]
# Fetched 144 kB in 1s (286 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package flac.
# (Reading database ... 146364 files and directories currently installed.)
# Preparing to unpack .../flac_1.3.2-1_amd64.deb ...
# Unpacking flac (1.3.2-1) ...
# Setting up flac (1.3.2-1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Collecting monotonic
#   Downloading https://files.pythonhosted.org/packages/ac/aa/063eca6a416f397bd99552c534c6d11d57f58f2e94c14780f3bbf818c4cf/monotonic-1.5-py2.py3-none-any.whl
# Installing collected packages: monotonic
# Successfully installed monotonic-1.5
# Requirement already satisfied: SpeechRecognition in /usr/local/lib/python3.6/dist-packages (3.8.1)

# %%
# ! pip install SpeechRecognition
## 환경설정
import speech_recognition as sr

recognizer = sr.Recognizer()
recognizer.energy_threshold = 300

## wav 파일 읽어오기
n=0
while True:
  n=n+1
  n=str(n)
  harvard_audio = sr.AudioFile('/content/drive/MyDrive/Colab Notebooks/data/audio/h/'+'h ('+n+').wav')

  with harvard_audio as source:
    audio = recognizer.record(source)

  try:
    a=recognizer.recognize_google(audio_data=audio, language="ko-KR")
    b=len(a)
    b=str(b)
    print(a)
  except:
    print(n)
  n=int(n)
  continue
# Out:
# 공부 하려고 했는데 미안해
# 오늘 오래 안 할 거예요 근데 맨날 이렇게 얘기하고 1시간 반씩
# 아니 오늘은 간단히
# 보고 싶었어요 나도 많이요
# 보고 싶어요 나는
# 울 아이브 처음 봐요
# 그래서 저는 좀 자주 하는 편 아닌가
# TV 하루 종일 해 주세요
# 제가 추천해드리고 싶은 CCM
# 처음 보시는 분들이 많으신가봐요
# 밥 먹었죠
# 최근에 있다
# 립 뭐 해
# 방미 노래 3시간 불렀는
# 아니요 안 드셨어요
# 요즘은 유튜브 안 하시나
# 아니야 유튜브 영상 꾸준히 찍고 있고요
# 그리고 저희 편집하는 언니도
# 열심히 다시 또 편집 하시고 계시고
# 곧 또 나올 것
# 박미 선생님 저학력 그치 사고 싶은데
# 위너 굿즈도 사고 싶고 아이콘 구조도 사고 싶어요 어쩌죠
# 심각하면 심각 수가 이렇게 나와 줄 수밖에 없죠
# 수현 선생님이라고 하시던데
# 장미허브 준엽이 놓고 아이콘 붙이냐 이것이 문제로다
# 여유가 되신다면
# gyakuten 위 디자인과 제작을 굉장히 잘 하기 때문에
# 저는 전부 다 추천해 드리고 싶은 마음이 있지만
# 아무래도 아무것도 이제 아닐까 하는 생각이 드네
# 배그를 안 하냐고 하는데
# 배그를 샀는데 얼마전에 샀는데
# 아직 한 번도 안 했어 요즘 게임을 안 해
# 볼살 빼는 법 좀 알려 주세요
# 메이플스토리는 안 옵니다
# 다이어트 어떻게 하셨어요 요즘 다시 했어요
# 근데 나한테 말할 때마다 다이어트 하고 있는 거 같은데
# 볼 성수기
# 볼 성수기
# 한국 성수기
# 일 없습니다
# 다이어트는 무조건 건강
# 운동과 식단
# 그것만이 살게 그것만이 답입니다
# 오 승연이가 조금 어른스러워진 거 같다고 하는데
# 조민 강아지는 밖에 있습니다
# 안녕 난 모찌 피치 야오 근데 진짜 뭐지
# 오늘은 뭐 안 먹어
# 먹으면 큰일 날 것 같은데요
# 제가 항상 두통이 조금 있는 날 이렇게 많이 붓고
# 근데 오늘 좀 두통이 아침으로 되어 있었는데
# 오늘도 여전히 부었네요 내일 그러면 안 되는데
# 기타 소리가 이상해
# 기타에서 플라스틱 소리 나
# 정한다고 정할 수 있는게 아니고
# 세 사람이 딱 얘기해서
# 팬덤 명을 만들어 하는 거
# 그렇습니까 아 그랬어
# 아 이게 다 완전 억양 다 다르더라고
# 저 화장 사투리 굉장히 좋아
# 너는 왜 이렇게 써
# 남자분들 여자분도
# 여자분 사투리 하면 너무 귀여워지고 남자분들 사투리 하시면 너무 매력 있으신데
# 제가 진짜 사투리 너무 배우고 싶어 가지고 진짜 맨날 사투리 쓰는 적 있어
# 어차피 뭐 하지 말라고 그래 가지고
# 문 앞에서 으르렁거리고 있네
# 그거 다 할 줄 몰라요
# 제가 영어를 배우고 있는데
# 영어를 우리 그 영어 선생님께서
# 영어 선생님께서 이제 아기를 또 가셔 가지고 셋째를 가지셔서
# 이제 다시 또 일본어 배우려고 하고 있어
# 뭔지 아세요
# 방금 한 말 전부 다 알아 들으셨나
# 알아 들으시는분 만 웃을 수 있을 거야
# 알아 듣는 사람만 웃을 수 있을까
# 안상건
# 그래 근데 많이 써먹으세요
# 유명한 팝송 들
# 왜 오시는 거 꼭 하나씩 있잖아
# 그냥 말하는 걸로 연습하지 마
# 굉장히 유용하게 써먹을 수 있음
# donaldson 아니면 렛잇고
# 김나희 노래
# 아니 제한적 영어는 이렇게 별 만들기
# 16시
# 모델이라 그런 건 아니고요
# 어떻게 이렇게 발음이 좋냐
# 말로 바꿀 수 있니
# 스포하면 안되니깐요 제가
# 더 못 잊겠어요 못 있는 건 아니고
# 더 궁금하신다면 애니 맹렬 교과서를 사서
# 읽어보시는 거 추천해 드립니다
# 처음부터 끝까지 다 읽었는데 책이 아니라
# 제가 굉장히 깔끔하게
# 모든 책을 잘 굉장히 깔끔하게
# 저기 그 절대 안 돼
# 아님 anglican 여기까지
# 짐은 천재야
# 쿠우쿠우 반 영화 코코
# 지금 필터 있는 거예요 필터 없애 드릴까
# 오줌 필터라고
# 어때 여러분 이렇게 할까
# 눈 아파요 눈 아플 정도
# 너무 예뻐요 여인
# 아니야 이거 하지 마
# 그거는
# 제발 하지 마세요 지메일 둘 중에 하나
# 어떻게 하면 좋을까요
# 함안 근처
# 나도 괜찮아
# 110
# 눈 눈 아플 정도라고
# 실명까지 가는 거면 알겠습니다
# 미니언즈가 주인공입니다
# 어때요
# 어 그건 괜찮다 돼
# 무필터 무필터
# 싫다고 그딴 거 하지 마요
# 다른 거 더 볼게요
# 얘도 약간 리비도 보이고
# 120
# 안 그래도 요즘 조회영역 보고
# 너무 무서워
# 123
# 엄마랑 같이 자
# 좀 이해가 안 되는데 맞아 좀 이해가 안 된다
# 이거 어떠신가요
# 이걸로
# 시계가 2분 드린다고 이게 2분이 내린게 보인다
# 의식의 흐름 같은 방송
# 맞아요 저 내일 그래
# 제가 오랜만에
# 유튜브에 잡지 피치 댓글을 보다가
# 나오면 쳐 가지고 쭉 보는데
# 다시 보는데 너무 웃긴 거예요
# 우리가 했는데
# 너무 말도 안 되게 웃긴 거예요
# 배꼽 잡고 웃었어요
# 악녀의 야자타임
# 부평에서 졌던 그
# 4층을 대한
# 카레를 불렀던 기억이 아예 하나도 안 나는 거야
# 아 진짜 그거 해보고 너무 놀러 가지
# 왜 그러는 거냐고 됐지
# 정신이 하나도 없었네
# 너무 웃기더라
# 한참 그것도 되겠어
# 멜로디 번호 가지고 즉흥으로 이제 노래 만든 거 그것도
# 흡착 맞는 거지 뭐 코드가 있고
# 그게 뭔데 아 진짜 너무 웃겨
# 어제 오빠랑 통화 했는데 내가 얼마 전에 구입을 보낸대
# 그 앱을 반드시 너무 웃겼다고
# 우리가 이렇게 웃겨 냐고
# 그 당신 그렇게 몰랐다
# 너무 웃겼다
# 오빠는 말만 들어도 없더라고
# 그 생각이 나기도 하고 그래서 그 이유를 탔음
# 유튜브에 있는 저의 영상을 또박 많이 보고 있는데
# 되게 재밌게 살았더라
# 꿀잼 꿀잼
# PT 여장 했던 거 그것도 있고
# 근황 토크
# 잘 근황은요
# 라면 먹은 거
# 요즘 그냥 뭐가 궁금합니까
# 뭐 하고 사는지
# 작업하면서 지내고 있고요
# 교회 활동 좀 열심히 하고 있고요
# 컴백이 아니라
# 앨범에 대해서
# 열심히 방향성에 대해서
# 고민을 하고 있어
# 뭐가 제일 나한테 잘 어울릴까
# 내 목소리에 가장 잘 어울릴까
# 그래도 이것저것 많이 커버하고 뭐 그러면서 지내고 있어
# 조금 조금씩이라도 만들어서
# 좋은 앨범 나오겠네요
# 맨날 그 얘기
# 앨범 다 만들면 진짜 올 거예요
# 차 너무 많이 잡아 줘
# 너무 많이 쪄 가지고
# 사춘기 상대 제 사진을 보면서 그때 제일 많이 빠졌을 때
# 상태 사진 보면서
# 매일 매일 운동하고
# 있어 여러분들께 지금이 각도가 굉장히 지금
# 한번도이 각도를 벗어나고 있지 않고 있어
# 끝날 때까지 이러고 있을게
# 요즘 꽂힌 노래
# 디즈니 OST 들
# 하도 엄청 듣고 있어
# all of my word
# 라푼젤 노래
# 미키마우스
# 미녀와 야수
# 뷰티 앤 더 비스트 너
# 바람에
# 이것저것 많이 듣고 있어
# 잔나비인데 노래도 엄청 많이
# 응 나 그거 들으면서 힐링
# 얼굴이 주먹자국 생겨
# 끌 때까지 이러고 있을 거라서 괜찮아
# 아니요 어제 술 안 먹습니다
# 술을 먹지 않습니다
# 특이하게 되시면 제가 꽂힌 라푼젤 노래는
# 이런 노래 할 거예요
# 제가 44
# 이런 뮤지컬 할 겁니다
# 저 이런 노래 너무 좋아요 이런 거 너무
# 너무 좋아 너무 좋아 너무
# 밥은 자살 할 때까지 적패 내 주셔야 돼
# 벌어 오셔야 돼
# 뮤지컬도 내 언젠가는 정말 진짜 꼭 하고 싶어
# 디즈니가 뮤지컬로 나온다
# 영화 뮤지컬로 나온다면 꼭 해보고 싶다
# 겨울왕국 안나 같은 그런 역할
# 잠버릇
# 216
# 돈 벌어도 없고 코도 안 걸고
# 막 그러지도 않는데 이렇게 많이 뒤척
# 오른쪽 왼쪽 많이 지쳐
# 뮤지컬 디즈니 뮤지컬 기억해
# 하고싶다
# 비긴 어게인 기대도 됩니까
# 굉장히 기대하고 있음
# 그 누구보다 제가 아마 제일 많이 기대하고 있어
# 저 진짜 요즘 하루에
# 비긴어게인 빨리 방송 했으면
# 이번에 티저가 나왔거든
# 항상 같이 있었으니까 그거 할 때도 항상 옆에 있었고 그러니까
# 당연히 너무 좋고 너무 힐링되는 거 알고 있어
# 진영아 선배님 팀은 한 번도 본 적이 없거든요
# 빨리 저도 방송 시작 했으면 좋겠어요 진짜 많이 부를 거야
# 댓글이 빨리 올라가는데 보이나요
# 진짜 빨리 올라가서 전부 다 열지는 못함
# 수면 바지 안 입어
# 디즈니 노래 이어 부른 거 들어 보셨어요 디즈니 메들리 틀어 봐
# 너무 좋더라고요 나중에 저도 한번 도전해 봐
# 수면바지 안 입은게 그렇게 오후 할 만한 것
# 저번 V 앱 때 빨간 수면바지입고
# 거울에 비친 제 다리에
# 직원 분께서 보내 주셨어
# 241
# 오늘 몇 분 부셨어요 오늘 일요일 거야 당연히 바쳐서 필리핀 갔다 오는 날인데
# 너무 오래돼서 까먹은 거 같아
# 기정이네 지금 딴데 말씀
# 나만 그것도 공개 될 걸
# 아이즈원
# 1시는 소식은 없나요
# 호주도 생각보다 한 소년을 찾으시는 분이 굉장히 그만하시고
# 오버 가고 나서 하이수현의 근황을 모르시는 분들도 굉장히 많으시더라구요
# 각자 앨범이 아직 안 나온 상태이기 때문에
# 상태 이구요
# 좋은 기회가 되면 하게 되지 않을까 싶긴 한데
# 스타일이 많이 달라져서
# 많이 그때보다 굉장히 많이 달라졌구나
# 그래도 기회가 된다면 하고 싶게 합니다
# 재방 아니고 본방이
# 다이노소어 학용품 패키지 산데 진짜 이뻐
# 다이노소어 학용품 패키지가 뭐
# 보이즈 굿즈
# 너도 좀 보내
# 하얀 패딩 괜찮아
# 262
# 엄청 들어 거의 검은색
# 새로 나왔어
# 265
# 왜 나만 돈 주고 왜
# 뭔지도 몰라
# 말이 되는 거야
# 안준영
# 어이구 잘 만든다고 아까 칭찬했는데 내가
# 시작할 때 얘기했는데
# 세상 살다 보면 이런 날도 있고 저런 일도 있는 거죠
# 편집 안돼요 우리 YG는 이런 걸로
# 담아두고 그러지 마
# 나도 마찬가지 뭐 그럴 수 있어
# 제작하는 굉장히 긴 기간 동안
# 그럴 수 있어
# 굉장히 바쁘시군요
# 모든 아티스트 분들을 제작 하시기 때문에
# 찬혁이 나이인데도 몰랐다는 건 약간
# 시작합니다
# 뭐 하나는 제가 몰라
# 오늘 영화를 못 봤어
# 거짓말하면 코가 길어진다
# 제발 들어 줬으면 좋겠어
# 거짓말 좀 해 줘
# 그럼 어떡해야 돼
# 288
# 달빛천사 ost 틀어 줘
# 어쨌든 잘 부친상 아니에요
# 저 땐 달빛 항상
# 저 땐 뭐 했는지 한번 맞춰봐
# 달빛천사 유아 애니메이션
# 말하는 스타일이기도 진짜 좋아
# 어 그래도 이게 잘 많이 올라와
# 그 노래 말씀이
# 슈가슈가룬 마지막 방송하는
# 생생하게 기억이 나
# 마지막 방송 안내 나 어떤 장면 있었나
# 손등에 다 뽀뽀하는 장면 있었어
# 이제 그거 보면서 하기
# 다 보고 나서 울고 있어
# 친구한테 바로 옆집에 사는 친구한테 전화
# 슈가슈가룬 끝났어
# 맞아 나도 봤어
# 수연아 너
# 아니 내가 왜 울어
# 안 되지
# 시리랑 쌍둥이 형제가 있거든
# 310
# 주황색이나 노란색이야 남자들 하트
# 모르겠다 가자
# 일이 있어서 참 재밌게 봐
# 빨강은 많이 없어요 빨강이 많이 빨강이 있어야 되는데
# 진정한 교사
# 벌꿀색한테 맞아
# 지금 효리네 민박 하고 있어요
# 박보검 나이
# 앞으로 가자
# 저도 앞으로 갈
# 저도 그거 보러 갈까
# 5분 후에 끌게요
# 마무리 해야 되니
# 말도 크게 나오고 있다고 하면 그거 봐야지
# 이거 재방 보면 되잖아요
# 저도 봐야 돼요 저도 보고 싶어
# 고등래퍼 봐요
# 여자 친구가 나갔어 써 가지고
# 누가 말했어 나와라
# 조금 보다
# 저는 부부 못 봐
# 우리는 민박은
# 재방 그것도 있다고 아니 근데 그건
# 배신이 아니라 여러분들
# 51분 봤으니까
# 고구마님 오늘 보는 것도 봐야지
# 한심하지
# 말씀하세요
# 내가 그런 사람이니까
# 내가 세상에서 제일 사랑하는
# 방송 끄지 말고 보면 안 돼
# 내가 분과 님 을 보낸 그 리액션 을 보겠다
# 그건 조금 그렇지 않을까
# 약간 좀 떨어질 수도 있고
# 아니 여러분
# 원래 간단하게 하려고 했거든 evf 오늘 내가 간다
# 항상 얘기하다 보면 너무 즐겁고 행복해서
# 여기 하나 1시간 1시간 반을 하게 되는데
# 마침 또 TV에 보고 문의 님께서 나오신다고 하시니까
# 가자 나는 그런 의견이 줘
# 351
# 아 전화 안 받아도 돼
# 353
# 일 때문에 너무 애처럼
# 하는 거 같은데 우리 편
# 누군데 화난 거
# 헝거 게임
# 불러 줘 일도 안 했어
# 얼굴 빨개져서 그런 거예요
# 아 이렇게 길어지는 거구나
# 안 볼 거야 나 이거 꺼져 꺼져 안 볼 거야
# 잡아 물어볼 거야
# 운동하면서 아침에 효리네 민박 보거든요
# 그때 볼 거야 지금 꺼도 안 보고 씻고 자요
# 실거미 올라와 있네
# 366
# 근데 진짜 장난친 거
# 진짜 씻고 잘 거야
# 몸이 별로 안 좋아서
# 오늘 머리가 좀 아파요 아침부터 아까부터 얘기를 했지
# 씻고 잘 거야
# TV를 잘 안 봐요 제가
# 진짜 이건 진짜
# 다시 원래대로 원상 복귀
# 안 길어져서 다시
# 씻고 자는 거 내가 인싸 스트레인저
# 나 진짜가 볼게요
# 진짜 머리가 아파서 그러는 거야
# 얼굴은 보고 자요
# 안녕
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-34661d0cda16> in <module>()
#      13   harvard_audio = sr.AudioFile('/content/drive/MyDrive/Colab Notebooks/data/audio/h/'+'h ('+n+').wav')
#      14
# ---> 15   with harvard_audio as source:
#      16     audio = recognizer.record(source)
#      17
#
# /usr/local/lib/python3.6/dist-packages/speech_recognition/__init__.py in __enter__(self)
#     201         try:
#     202             # attempt to read the file as WAV
# --> 203             self.audio_reader = wave.open(self.filename_or_fileobject, "rb")
#     204             self.little_endian = True  # RIFF WAV is a little-endian format (most ``audioop`` operations assume that the frames are stored in little-endian form)
#     205         except (wave.Error, EOFError):
#
# /usr/lib/python3.6/wave.py in open(f, mode)
#     497             mode = 'rb'
#     498     if mode in ('r', 'rb'):
# --> 499         return Wave_read(f)
#     500     elif mode in ('w', 'wb'):
#     501         return Wave_write(f)
#
# /usr/lib/python3.6/wave.py in __init__(self, f)
#     157         self._i_opened_the_file = None
#     158         if isinstance(f, str):
# --> 159             f = builtins.open(f, 'rb')
#     160             self._i_opened_the_file = f
#     161         # else, assume it is an open file object already
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/data/audio/h/h (381).wav'

# %%
# ! pip install SpeechRecognition
## 환경설정
import speech_recognition as sr

recognizer = sr.Recognizer()
recognizer.energy_threshold = 300

## wav 파일 읽어오기
harvard_audio = sr.AudioFile("/data/a (6).wav")

with harvard_audio as source:
    audio = recognizer.record(source)

recognizer.recognize_google(audio_data=audio, language="ko-KR")
# Out:
# '벌써 자야 해요 왜냐하면 내일 인기 가요 있잖아요 내일 인기 가요 하고 창원에도 있는데 내일은 새벽 3시에 나갑니다'

# %%
f = open('/content/drive/MyDrive/Colab Notebooks/data/txt rev/w.txt')
n=0
while True:
    n=n+1
    n=str(n)
    line = f.readline()
    if not line: break
    a=len(line.strip())
    a=str(a)
    print ('w ('+n+').wav'+'|'+line.strip('\n')+'|'+a)
    n=int(n)
f.close()

# %%
f = open('/data/txt/integrateaw.txt')
fw = open('/data/txt/integrateaww.txt', 'w')
while True:
  line=f.readline()
  if not line: break
  data=line.split('|')
  cdata=data[0]+'|'+data[1]+'|1\n'
  print(cdata.strip())
  fw.write(cdata)
f.close

# %%
import os
n=0
while True:
  n=n+1
  n=str(n)
  os.remove('/content/drive/MyDrive/Colab Notebooks/data/reserve/radio/1 ('+n+').mp3')
  print("remove the"+n)
  n=int(n)
  continue
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-cbac657f93a3> in <module>()
#       4   n=n+1
#       5   n=str(n)
# ----> 6   os.remove('/content/drive/MyDrive/Colab Notebooks/data/reserve/radio/1 ('+n+').mp3')
#       7   print("remove the"+n)
#       8   n=int(n)
#
# OSError: [Errno 5] Input/output error: '/content/drive/MyDrive/Colab Notebooks/data/reserve/radio/1 (1).mp3'
